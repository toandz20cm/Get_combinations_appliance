# %%
import numpy
from numpy import random

#Fan = F
#Hairdryer = HD
#LAPTOP CHARGER = LC
#Phone Charger = PC
#Lamp = L

# %%
#Fan + Hairdryer
Mean_FHD = [332.5394, 1.4789]           #[E(X1) + E(X2), E(Y1) + E(Y2)]
COV_FHD =  [[107.2683, 0.3664],
            [0.3664,0.001604]]

FHD = random.multivariate_normal(Mean_FHD, COV_FHD, 1000)
for sample in FHD:
    print(sample)
# Out:
# [349.54081758   1.50496405]
# [334.74776391   1.49562237]
# [338.8829608    1.48226277]
# [334.21547499   1.46235283]
# [327.89126498   1.48892938]
# [353.5883811    1.56263888]
# [327.17248394   1.46983999]
# [330.57964205   1.4658087 ]
# [332.32832163   1.50765639]
# [345.74193415   1.53998522]
# [327.7022834    1.48508864]
# [332.89005256   1.49271158]
# [345.40926129   1.53842305]
# [322.92486145   1.4605329 ]
# [342.75208842   1.50917167]
# [360.48604547   1.56284852]
# [321.92631925   1.47429036]
# [347.58807166   1.55299824]
# [341.36771741   1.49445667]
# [330.88328652   1.42889393]
# [325.26743844   1.46256721]
# [322.88417727   1.46085455]
# [325.62642398   1.45397828]
# [329.29982737   1.47325662]
# [319.94725618   1.45811168]
# [321.19038209   1.43914617]
# [323.50646379   1.42358022]
# [340.82855438   1.48900801]
# [314.00353127   1.38689917]
# [331.79814478   1.48975245]
# [341.16546292   1.4971267 ]
# [320.96601962   1.43371884]
# [315.16599989   1.40578704]
# ...
